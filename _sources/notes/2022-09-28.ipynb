# %% [markdown]
# # Fixing Data representations
#
#
# ## Admin
#
# - next assignment posted tonight.
#
#
# ### a4 TLDR:
# - Review how your new dataset manipulation skills could have helped you in A2 or A3.
# - clean provided (in the template) datasets
#   - do tiny EDA to show complete;
#   - add more EDA to get summarize and visualize
#   - clean a specific dataset for access level 2 or python level 2 also; do both if you need all 3 achievments (prepare, access, python)
# - Study some examples and notice patterns in data clearning
#
# ### Portfolio update
#
# ````{margin}
# ```{note}
# The portfolio is open ended intentionally.  I want you to learn these skills a
# little bit deeper than you have for the assignments, which is a little bit
# deeper than we cover in class and show me that you learned.  I do *not* want you
# to spend too much effort guessing what I want. I will look at what you submit
# for evidence of learning and assess that.  There is not a single "right" answer.
# ```
# ````
#
#
# - merge in your work from assignment 1
# - portoflio will be due in ~2 weeks start planning
# - read the [instructions](portfolioindex) and example [ideas](check1ideas); there will be time for q&a on Friday
# - you can also create an outline and get feedback on your plan using an issue on your portflio repo
#
#
# ## Review Filtering

# %%
import pandas as pd

# %% [markdown]
# We can also filter using the `isin` method to compare each item in a column to a list
#
# ````{margin}
# ```{note}
# You can see more about [groupby](groupby-detail) in notes from last week.
# ```
# ````

# %%
arabica_data_url = 'https://raw.githubusercontent.com/jldbc/coffee-quality-database/master/data/arabica_data_cleaned.csv'
# load the data
coffee_df = pd.read_csv(arabica_data_url)
# get total bags per country
bags_per_country_df = coffee_df.groupby('Country.of.Origin')['Number.of.Bags'].sum()

# sort descending, keep only the top 10 and pick out only the country names
top_bags_country_list = bags_per_country_df.sort_values(ascending=False)[:10].index

# filter the original data for only the countries in the top list
top_coffee_df = coffee_df[coffee_df['Country.of.Origin'].isin(top_bags_country_list)]

# %% [markdown]
# Yes this is a Series, not a data Frame, but a DataFrame is built of Series, so this is a small error in naming. `top_bags_country_list` is also an `Index` not a `list` but the names need to give an idea, not necessarily be precise so my choices are okay, but could be better.

# %%
type(coffee_df['Number.of.Bags'])
# Out:
# pandas.core.series.Series

# %%
type(coffee_df.loc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# We can look at the final result

# %%
top_coffee_df.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           1  Arabica                 metad plc          Ethiopia
# 1           2  Arabica                 metad plc          Ethiopia
# 2           3  Arabica  grounds for health admin         Guatemala
# 3           4  Arabica       yidnekachew dabessa          Ethiopia
# 4           5  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# 0      metad agricultural developmet plc      1950-2200  ...  Green
# 1      metad agricultural developmet plc      1950-2200  ...  Green
# 2                                    NaN  1600 - 1800 m  ...    NaN
# 3  yidnekachew debessa coffee plantation      1800-2200  ...  Green
# 4      metad agricultural developmet plc      1950-2200  ...  Green
#
#   Category.Two.Defects        Expiration                  Certification.Body  \
# 0                    0   April 3rd, 2016  METAD Agricultural Development plc
# 1                    1   April 3rd, 2016  METAD Agricultural Development plc
# 2                    0    May 31st, 2011        Specialty Coffee Association
# 3                    2  March 25th, 2016  METAD Agricultural Development plc
# 4                    2   April 3rd, 2016  METAD Agricultural Development plc
#
#                       Certification.Address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       Certification.Contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#   altitude_low_meters altitude_high_meters altitude_mean_meters
# 0              1950.0               2200.0               2075.0
# 1              1950.0               2200.0               2075.0
# 2              1600.0               1800.0               1700.0
# 3              1800.0               2200.0               2000.0
# 4              1950.0               2200.0               2075.0
#
# [5 rows x 44 columns]

# %%
top_coffee_df.shape, coffee_df.shape
# Out:
# ((952, 44), (1311, 44))

# %% [markdown]
# ## Fixing a Column
#
# In tidy data each column is exactly one variable. Let's look at the `Bag.Weight`

# %%
coffee_df['Bag.Weight'].sample(10)
# Out:
# 792     100 lbs
# 823        2 kg
# 732       60 kg
# 238        1 kg
# 406        1 kg
# 530       70 kg
# 172       30 kg
# 453        1 kg
# 1247      5 lbs
# 185       70 kg
# Name: Bag.Weight, dtype: object

# %% [markdown]
# This is actually two pieces of information, the value measured and the units used.  In addition to the fact that there are multiple units, even if we could convert them, we cannot do math on these because they're strings. (notice it says "object" as the type)
#
# Series have a `str` attribute so we can apply base python string methods to each value in a column.

# %%
coffee_df['Bag.Weight'].str

# %% [markdown]
# What we want is to split it

# %%
coffee_df['Bag.Weight'].str.split(' ').sample(10)
# Out:
# 751      [1, kg]
# 29      [50, kg]
# 1275     [1, kg]
# 175      [2, kg]
# 526     [60, kg]
# 796     [60, kg]
# 818     [59, kg]
# 931      [1, kg]
# 511      [1, kg]
# 434     [60, kg]
# Name: Bag.Weight, dtype: object

# %% [markdown]
# Since this looks good, we can save it to a variable.

# %%
split_bw = coffee_df['Bag.Weight'].str.split(' ')

# %% [markdown]
# We still have one problem, each element contains a list.

# %%
type(split_bw[0])
# Out:
# list

# %% [markdown]
# What we want is a `DataFrame` with two columns, one of the first value and one of the second value for each list.
#
# A `DataFrame` is build of Series which are each row (and each column) the lists we have are each the content that we want to put in one Series and then stack them all together.
#
# To do this, we can cast each list to a `Series` using the `apply` method which automatically stacks Series or DataFrames back together after applying a function to each row (or column).
#
# Recall that in python, we can use types as functions to cast

# %%
num = '2'

# %%
type(int(num))
# Out:
# int

# %%
type(num)
# Out:
# str

# %% [markdown]
# So, back to our real problem:

# %%
split_bw.apply(pd.Series)
# Out:
#        0    1
# 0     60   kg
# 1     60   kg
# 2      1  NaN
# 3     60   kg
# 4     60   kg
# ...   ..  ...
# 1306   1   kg
# 1307   2   kg
# 1308  69   kg
# 1309   1   kg
# 1310  69   kg
#
# [1311 rows x 2 columns]

# %% [markdown]
# This looks good, but these columns are not very informative, so we can rename them.
#
# Rename can take many different inputs and be applied on lots of parts, but we will use it with a dictionary that serves as a mapping (like the mathematical sense of mapping; like a function).  It will change the column with each key to the value.

# %%
split_df = split_bw.apply(pd.Series).rename(columns={0:'Weight',1:'Units'})
split_df
# Out:
#      Weight Units
# 0        60    kg
# 1        60    kg
# 2         1   NaN
# 3        60    kg
# 4        60    kg
# ...     ...   ...
# 1306      1    kg
# 1307      2    kg
# 1308     69    kg
# 1309      1    kg
# 1310     69    kg
#
# [1311 rows x 2 columns]

# %% [markdown]
# This is good, but it's only the one column.  We can use concat to put them together.

# %%
pd.concat([coffee_df,split_df],axis=1).head(2)
# Out:
#    Unnamed: 0  Species      Owner Country.of.Origin  Farm.Name Lot.Number  \
# 0           1  Arabica  metad plc          Ethiopia  metad plc        NaN
# 1           2  Arabica  metad plc          Ethiopia  metad plc        NaN
#
#         Mill ICO.Number                            Company   Altitude  ...  \
# 0  metad plc  2014/2015  metad agricultural developmet plc  1950-2200  ...
# 1  metad plc  2014/2015  metad agricultural developmet plc  1950-2200  ...
#
#         Expiration                  Certification.Body  \
# 0  April 3rd, 2016  METAD Agricultural Development plc
# 1  April 3rd, 2016  METAD Agricultural Development plc
#
#                       Certification.Address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       Certification.Contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#   altitude_low_meters altitude_high_meters altitude_mean_meters Weight Units
# 0              1950.0               2200.0               2075.0     60    kg
# 1              1950.0               2200.0               2075.0     60    kg
#
# [2 rows x 46 columns]

# %% [markdown]
# Why `axis=1` again?
#
# Let's look at the other one.

# %%
bad_concat = pd.concat([coffee_df,split_df],axis=0)
bad_concat.shape
# Out:
# (2622, 46)

# %% [markdown]
# It has double the rows
# ```{important}
# checking the shape is the first thing to do to see if you did the right one
# ```
#
# and the bottom of it most columns are NaN (null, missing)

# %%
bad_concat.tail()
# Out:
#       Unnamed: 0 Species Owner Country.of.Origin Farm.Name Lot.Number Mill  \
# 1306         NaN     NaN   NaN               NaN       NaN        NaN  NaN
# 1307         NaN     NaN   NaN               NaN       NaN        NaN  NaN
# 1308         NaN     NaN   NaN               NaN       NaN        NaN  NaN
# 1309         NaN     NaN   NaN               NaN       NaN        NaN  NaN
# 1310         NaN     NaN   NaN               NaN       NaN        NaN  NaN
#
#      ICO.Number Company Altitude  ... Expiration Certification.Body  \
# 1306        NaN     NaN      NaN  ...        NaN                NaN
# 1307        NaN     NaN      NaN  ...        NaN                NaN
# 1308        NaN     NaN      NaN  ...        NaN                NaN
# 1309        NaN     NaN      NaN  ...        NaN                NaN
# 1310        NaN     NaN      NaN  ...        NaN                NaN
#
#       Certification.Address Certification.Contact unit_of_measurement  \
# 1306                    NaN                   NaN                 NaN
# 1307                    NaN                   NaN                 NaN
# 1308                    NaN                   NaN                 NaN
# 1309                    NaN                   NaN                 NaN
# 1310                    NaN                   NaN                 NaN
#
#      altitude_low_meters altitude_high_meters altitude_mean_meters Weight  \
# 1306                 NaN                  NaN                  NaN      1
# 1307                 NaN                  NaN                  NaN      2
# 1308                 NaN                  NaN                  NaN     69
# 1309                 NaN                  NaN                  NaN      1
# 1310                 NaN                  NaN                  NaN     69
#
#      Units
# 1306    kg
# 1307    kg
# 1308    kg
# 1309    kg
# 1310    kg
#
# [5 rows x 46 columns]

# %% [markdown]
# (unpacking-jsons)=
# ## Unpacking Jsons

# %%
rhodyprog4ds_gh_events_url = 'https://api.github.com/orgs/rhodyprog4ds/events'

# %%
course_gh_df = pd.read_json(rhodyprog4ds_gh_events_url)
course_gh_df.head()
# Out:
#             id         type  \
# 0  25344402964  CreateEvent
# 1  25344398675    PushEvent
# 2  25342083235    PushEvent
# 3  25341998257    PushEvent
# 4  25337507441    PushEvent
#
#                                                actor  \
# 0  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 1  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 2  {'id': 41898282, 'login': 'github-actions[bot]...
# 3  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 4  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                 repo  \
# 0  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 1  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 2  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 3  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 4  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
#
#                                              payload  public  \
# 0  {'ref': 'c28', 'ref_type': 'tag', 'master_bran...    True
# 1  {'push_id': 11716960749, 'size': 1, 'distinct_...    True
# 2  {'push_id': 11715655053, 'size': 1, 'distinct_...    True
# 3  {'push_id': 11715611559, 'size': 1, 'distinct_...    True
# 4  {'push_id': 11713342480, 'size': 1, 'distinct_...    True
#
#                  created_at                                                org
# 0 2022-11-19 03:18:33+00:00  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 1 2022-11-19 03:17:50+00:00  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 2 2022-11-18 22:54:00+00:00  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 3 2022-11-18 22:47:06+00:00  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 4 2022-11-18 18:09:53+00:00  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...

# %% [markdown]
# We want to transform each one of those from a dictionary like thing into a
# row in a data frame.

# %%
type(course_gh_df['actor'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Recall, that base python types can be used as function, to cast an object from
# type to another.

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
str(5)
# Out:
# '5'

# %% [markdown]
# To unpack one column we can cast each element of the column to a series and then stack them back together.
#
# First, let's look at one row of one column

# %%
course_gh_df['actor'][0]
# Out:
# {'id': 10656079,
#  'login': 'brownsarahm',
#  'display_login': 'brownsarahm',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/brownsarahm',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10656079?'}

# %% [markdown]
# Now let's cast it to a Series

# %%
pd.Series(course_gh_df['actor'][0])
# Out:
# id                                                        10656079
# login                                                  brownsarahm
# display_login                                          brownsarahm
# gravatar_id
# url                       https://api.github.com/users/brownsarahm
# avatar_url       https://avatars.githubusercontent.com/u/10656079?
# dtype: object

# %% [markdown]
# What we want is to do this over and over and stack them.
#
#  The `apply` method does this for us, in one compact step.

# %%
course_gh_df['actor'].apply(pd.Series)
# Out:
#           id                login   display_login gravatar_id  \
# 0   10656079          brownsarahm     brownsarahm
# 1   10656079          brownsarahm     brownsarahm
# 2   41898282  github-actions[bot]  github-actions
# 3   10656079          brownsarahm     brownsarahm
# 4   41898282  github-actions[bot]  github-actions
# 5   41898282  github-actions[bot]  github-actions
# 6   10656079          brownsarahm     brownsarahm
# 7   10656079          brownsarahm     brownsarahm
# 8   41898282  github-actions[bot]  github-actions
# 9   41898282  github-actions[bot]  github-actions
# 10  10656079          brownsarahm     brownsarahm
# 11  10656079          brownsarahm     brownsarahm
# 12  41898282  github-actions[bot]  github-actions
# 13  10656079          brownsarahm     brownsarahm
# 14  10656079          brownsarahm     brownsarahm
# 15  10656079          brownsarahm     brownsarahm
# 16  41898282  github-actions[bot]  github-actions
# 17  10656079          brownsarahm     brownsarahm
# 18  41898282  github-actions[bot]  github-actions
# 19  10656079          brownsarahm     brownsarahm
# 24  https://avatars.githubusercontent.com/u/41898282?
# 25  https://avatars.githubusercontent.com/u/10656079?
# 26  https://avatars.githubusercontent.com/u/10656079?
# 27  https://avatars.githubusercontent.com/u/10656079?
# 28  https://avatars.githubusercontent.com/u/41898282?
# 29  https://avatars.githubusercontent.com/u/10656079?

# %% [markdown]
# How can we do this for all of the columns and put them back together after?
#
# First, let's make a list of the columns we need to convert.

# %%
js_cols = ['actor','repo','payload','org']

# %% [markdown]
# When we use `.apply(pd.Series)` we get a a DataFrame.

# %%
type(course_gh_df['actor'].apply(pd.Series))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `pd.concat` takes a list of DataFrames and puts the together in one DataFrame.
#
# to illustrate, it's nice to make small dataFrames.

# %%
df1 = pd.DataFrame([[1,2,3],[3,4,7]], columns = ['A','B','t'])
df2 = pd.DataFrame([[10,20,30],[30,40,70]], columns = ['AA','BB','t'])
df1
# Out:
#    A  B  t
# 0  1  2  3
# 1  3  4  7

# %%
df2
# Out:
#    AA  BB   t
# 0  10  20  30
# 1  30  40  70

# %% [markdown]
# If we use concat with the default settings, it stacks them vertically and aligns any columns that have the same name.

# %%
pd.concat([df1,df2])
# Out:
#      A    B   t    AA    BB
# 0  1.0  2.0   3   NaN   NaN
# 1  3.0  4.0   7   NaN   NaN
# 0  NaN  NaN  30  10.0  20.0
# 1  NaN  NaN  70  30.0  40.0

# %% [markdown]
# So, since the original DataFrames were both 2 rows with 3 columns each, with one column name appearing in both, we end up with a new DataFrame with shape (4,5) and it fills with `NaN` in the top right and the bottom left.

# %%
pd.concat([df1,df2]).shape
# Out:
# (4, 5)

# %% [markdown]
# We can use the `axis` parameter to tell it how to combine them. The default is `axis=0`, but `axis=1` will combine along rows.

# %%
pd.concat([df1,df2], axis =1)
# Out:
#    A  B  t  AA  BB   t
# 0  1  2  3  10  20  30
# 1  3  4  7  30  40  70

# %% [markdown]
# So now we get no NaN values, because both DataFrames have the same number of rows and the same index.

# %%
df1.index == df2.index
# Out:
# array([ True,  True])

# %% [markdown]
# and we have a total of 6 columns and 2 rows.

# %%
pd.concat([df1,df2], axis =1).shape
# Out:
# (2, 6)

# %% [markdown]
# Back to our gh data, we want to make a list of DataFrames where each DataFrame corresponds to one of the columns in the original DataFrame, but unpacked and then stack them horizontally (`axis=1`) because each DataFrame in the list is based on the same original DataFrame, they again have the same index.

# %%
pd.concat([course_gh_df[cur_col].apply(pd.Series) for cur_col in js_cols],
         axis=1)
# Out:
#           id                login   display_login gravatar_id  \
# 0   10656079          brownsarahm     brownsarahm
# 1   10656079          brownsarahm     brownsarahm
# 2   41898282  github-actions[bot]  github-actions
# 3   10656079          brownsarahm     brownsarahm
# 4   41898282  github-actions[bot]  github-actions
# 5   41898282  github-actions[bot]  github-actions
# 6   10656079          brownsarahm     brownsarahm
# 7   10656079          brownsarahm     brownsarahm
# 8   41898282  github-actions[bot]  github-actions
# 9   41898282  github-actions[bot]  github-actions
# 10  10656079          brownsarahm     brownsarahm
# 11  10656079          brownsarahm     brownsarahm
# 12  41898282  github-actions[bot]  github-actions
# 7   ...  63727888c8534e30904a3e861d5d7577aaca2f11
# 8   ...  f78b6725c4da8ad05aaf13b4b35675d63f83df23
# 9   ...  86c437bd06ef3316dfa757de1950afec91cd7f1e
# 10  ...  ac15626f7d5446ad75b2c5275d51064da3fef8f5
# 11  ...  49f8bc6e20fb6121c59a3b1ffd336348adda54bd
# 12  ...  2b3c332b0a9f519caf5db7f587b93283357b79c5
# 13  ...                                       NaN
# 14  ...                                       NaN
# 15  ...  327f0de48096628636911e6735f51af6c66291bb
# 16  ...  27fd4444bdd9269fb83fd4660009b7ce83828717
# 17  ...  972fa20a0af61e6f4cc0a16cecee0da188c0055d
# 18  ...  37222cbb373ca45d08e61b7a68f62f121bdf5272
# 19  ...  992241ff235eaca1af3dc481dd0b9271e8b20256
# 20  ...  e0a94cb4ed2cf6acc901e4110f89fe87934890ab
# 21  ...                                       NaN
# 22  ...  f801ef370cb979ad716d9b2ea12f17d61c74ba6d
# 23  ...                                       NaN
# 24  ...  f8b9308f2355fdd856b458aa6b56d9af41496e94
# 25  ...                                       NaN
# 26  ...                                       NaN
# 27  ...  d06b0ec8d75bcf0d035cf189f8430174e7b1cb5f
# 28  ...  69b5b579a9e5df7dc5fb2afeaad051ce841050a6
# 29  ...  8eb670dc6d70578e1324c8c2ba475245fe27cd1e
#
#                                               commits     action  \
# 0                                                 NaN        NaN
# 1   [{'sha': '881aeec1cac8e2df50ca1f76b6511191e2e2...        NaN
# 2   [{'sha': '877af3815420d0575ca99daf6da6e85325ae...        NaN
# 3   [{'sha': 'ac2160155ae965ac5244413ee4c1dbaaeb35...        NaN
# 4   [{'sha': 'ad28375f9703319d32ebb6c12da364b6497b...        NaN
# 5   [{'sha': '4a55b9e6de7dab488d6e94acd3582817b12c...        NaN
# 6   [{'sha': 'abebc1f0a53d61324d4eb065f5382e0e9e9e...        NaN
# 7   [{'sha': '68204526add6f1520f015b7d5d56623b788a...        NaN
# 8   [{'sha': 'dfcb25065771ab6bda4a8d71c8dfad644d48...        NaN
# 9   [{'sha': 'f78b6725c4da8ad05aaf13b4b35675d63f83...        NaN
# 10  [{'sha': '63727888c8534e30904a3e861d5d7577aaca...        NaN
# 11  [{'sha': 'ac15626f7d5446ad75b2c5275d51064da3fe...        NaN
# 12  [{'sha': '86c437bd06ef3316dfa757de1950afec91cd...        NaN
# 13                                                NaN  published
# 14                                                NaN        NaN
# 15  [{'sha': 'e739321a0bc750cf81bb9ae6be99c2bebebc...        NaN
# 16  [{'sha': '2b3c332b0a9f519caf5db7f587b93283357b...        NaN
# 17  [{'sha': 'e286a7fe8b506fd2925989de6656aa86871e...        NaN
# 18  [{'sha': '27fd4444bdd9269fb83fd4660009b7ce8382...        NaN
# 19  [{'sha': '972fa20a0af61e6f4cc0a16cecee0da188c0...        NaN
# 20  [{'sha': '37222cbb373ca45d08e61b7a68f62f121bdf...        NaN
# 21                                                NaN     closed
# 22  [{'sha': '992241ff235eaca1af3dc481dd0b9271e8b2...        NaN
# 23                                                NaN     closed
# 24  [{'sha': 'e0a94cb4ed2cf6acc901e4110f89fe879348...        NaN
# 25                                                NaN  published
# 26                                                NaN        NaN
# 27  [{'sha': 'f801ef370cb979ad716d9b2ea12f17d61c74...        NaN
# 28  [{'sha': 'f8b9308f2355fdd856b458aa6b56d9af4149...        NaN
# 29  [{'sha': 'd06b0ec8d75bcf0d035cf189f8430174e7b1...        NaN
#
#                                               release  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/rhodypro...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/rhodypro...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                                 issue        id         login  \
# 0                                                 NaN  69595187  rhodyprog4ds
# 1                                                 NaN  69595187  rhodyprog4ds
# 2                                                 NaN  69595187  rhodyprog4ds
# 3                                                 NaN  69595187  rhodyprog4ds
# 4                                                 NaN  69595187  rhodyprog4ds
# 5                                                 NaN  69595187  rhodyprog4ds
# 6                                                 NaN  69595187  rhodyprog4ds
# 7                                                 NaN  69595187  rhodyprog4ds
# 8                                                 NaN  69595187  rhodyprog4ds
# 9                                                 NaN  69595187  rhodyprog4ds
# 10                                                NaN  69595187  rhodyprog4ds
# 11                                                NaN  69595187  rhodyprog4ds
# 12                                                NaN  69595187  rhodyprog4ds
# 13                                                NaN  69595187  rhodyprog4ds
# 14                                                NaN  69595187  rhodyprog4ds
# 15                                                NaN  69595187  rhodyprog4ds
# 16                                                NaN  69595187  rhodyprog4ds
# 17                                                NaN  69595187  rhodyprog4ds
# 18                                                NaN  69595187  rhodyprog4ds
# 19                                                NaN  69595187  rhodyprog4ds
# 20                                                NaN  69595187  rhodyprog4ds
# 21  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 22                                                NaN  69595187  rhodyprog4ds
# 23  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 24                                                NaN  69595187  rhodyprog4ds
# 25                                                NaN  69595187  rhodyprog4ds
# 26                                                NaN  69595187  rhodyprog4ds
# 27                                                NaN  69595187  rhodyprog4ds
# 28                                                NaN  69595187  rhodyprog4ds
# 29                                                NaN  69595187  rhodyprog4ds
#
#    gravatar_id                                       url  \
# 0               https://api.github.com/orgs/rhodyprog4ds
# 1               https://api.github.com/orgs/rhodyprog4ds
# 2               https://api.github.com/orgs/rhodyprog4ds
# 3               https://api.github.com/orgs/rhodyprog4ds
# 4               https://api.github.com/orgs/rhodyprog4ds
# 5               https://api.github.com/orgs/rhodyprog4ds
# 6               https://api.github.com/orgs/rhodyprog4ds
# 7               https://api.github.com/orgs/rhodyprog4ds
# 8               https://api.github.com/orgs/rhodyprog4ds
# 9               https://api.github.com/orgs/rhodyprog4ds
# 10              https://api.github.com/orgs/rhodyprog4ds
# 11              https://api.github.com/orgs/rhodyprog4ds
# 12              https://api.github.com/orgs/rhodyprog4ds
# 13              https://api.github.com/orgs/rhodyprog4ds
# 14              https://api.github.com/orgs/rhodyprog4ds
# 15              https://api.github.com/orgs/rhodyprog4ds
# 16              https://api.github.com/orgs/rhodyprog4ds
# 17              https://api.github.com/orgs/rhodyprog4ds
# 18              https://api.github.com/orgs/rhodyprog4ds
# 19              https://api.github.com/orgs/rhodyprog4ds
# 20              https://api.github.com/orgs/rhodyprog4ds
# 21              https://api.github.com/orgs/rhodyprog4ds
# 22              https://api.github.com/orgs/rhodyprog4ds
# 23              https://api.github.com/orgs/rhodyprog4ds
# 24              https://api.github.com/orgs/rhodyprog4ds
# 25              https://api.github.com/orgs/rhodyprog4ds
# 26              https://api.github.com/orgs/rhodyprog4ds
# 27              https://api.github.com/orgs/rhodyprog4ds
# 28              https://api.github.com/orgs/rhodyprog4ds
# 29              https://api.github.com/orgs/rhodyprog4ds
#
#                                            avatar_url
# 0   https://avatars.githubusercontent.com/u/69595187?
# 1   https://avatars.githubusercontent.com/u/69595187?
# 2   https://avatars.githubusercontent.com/u/69595187?
# 3   https://avatars.githubusercontent.com/u/69595187?
# 4   https://avatars.githubusercontent.com/u/69595187?
# 5   https://avatars.githubusercontent.com/u/69595187?
# 6   https://avatars.githubusercontent.com/u/69595187?
# 7   https://avatars.githubusercontent.com/u/69595187?
# 8   https://avatars.githubusercontent.com/u/69595187?
# 9   https://avatars.githubusercontent.com/u/69595187?
# 10  https://avatars.githubusercontent.com/u/69595187?
# 11  https://avatars.githubusercontent.com/u/69595187?
# 12  https://avatars.githubusercontent.com/u/69595187?
# 13  https://avatars.githubusercontent.com/u/69595187?
# 14  https://avatars.githubusercontent.com/u/69595187?
# 15  https://avatars.githubusercontent.com/u/69595187?
# 16  https://avatars.githubusercontent.com/u/69595187?
# 17  https://avatars.githubusercontent.com/u/69595187?
# 18  https://avatars.githubusercontent.com/u/69595187?
# 19  https://avatars.githubusercontent.com/u/69595187?
# 20  https://avatars.githubusercontent.com/u/69595187?
# 21  https://avatars.githubusercontent.com/u/69595187?
# 22  https://avatars.githubusercontent.com/u/69595187?
# 23  https://avatars.githubusercontent.com/u/69595187?
# 24  https://avatars.githubusercontent.com/u/69595187?
# 25  https://avatars.githubusercontent.com/u/69595187?
# 26  https://avatars.githubusercontent.com/u/69595187?
# 27  https://avatars.githubusercontent.com/u/69595187?
# 28  https://avatars.githubusercontent.com/u/69595187?
# 29  https://avatars.githubusercontent.com/u/69595187?
#
# [30 rows x 28 columns]

# %% [markdown]
# ```{admonition} Try it Yourself
# examine the list of DataFrames to see what structure they share and do not share
# ```
#
# In this case we get the same 30 rows, beacuse that's what the API gave us and turned our 4 columns from `js_cols` into 26 columns.

# %%
pd.concat([course_gh_df[cur_col].apply(pd.Series) for cur_col in js_cols],
         axis=1).shape
# Out:
# (30, 28)

# %% [markdown]
# If we had used the default, we'd end up with 120 rows (30*4) and we have only 19 columns, because there are subfield names that are shared across the original columns. (eg most have an `id`)
# ````{margin}
# ```{admonition} Try it yourself
# How could you anticipate how many are shared?
# ```
# ````

# %%
pd.concat([course_gh_df[cur_col].apply(pd.Series) for cur_col in js_cols],
         axis=0).shape
# Out:
# (120, 21)

# %% [markdown]
# we might want to rename the new columns so that they have the original column
# name prepended to the new name. This will help us distinguish between the different `id` columns
#
# pandas has a `rename` method for this.
#
# and this is another job for lambdas.

# %%
pd.concat([course_gh_df[cur_col].apply(pd.Series).rename(columns = lambda c: cur_col + '_' +c)
           for cur_col in js_cols],
         axis=1)
# Out:
#     actor_id          actor_login actor_display_login actor_gravatar_id  \
# 0   10656079          brownsarahm         brownsarahm
# 1   10656079          brownsarahm         brownsarahm
# 2   41898282  github-actions[bot]      github-actions
# 3   10656079          brownsarahm         brownsarahm
# 4   41898282  github-actions[bot]      github-actions
# 5   41898282  github-actions[bot]      github-actions
# 6   10656079          brownsarahm         brownsarahm
# 7   10656079          brownsarahm         brownsarahm
# 8   41898282  github-actions[bot]      github-actions
# 9   41898282  github-actions[bot]      github-actions
# 10  10656079          brownsarahm         brownsarahm
# 11  10656079          brownsarahm         brownsarahm
# 12  41898282  github-actions[bot]      github-actions
# 13  10656079          brownsarahm         brownsarahm
# 14  10656079          brownsarahm         brownsarahm
# 15  10656079          brownsarahm         brownsarahm
# 16  41898282  github-actions[bot]      github-actions
# 17  10656079          brownsarahm         brownsarahm
# 18  41898282  github-actions[bot]      github-actions
# 19  10656079          brownsarahm         brownsarahm
# 20  41898282  github-actions[bot]      github-actions
# 21  10656079          brownsarahm         brownsarahm
# 22  10656079          brownsarahm         brownsarahm
# 23  10656079          brownsarahm         brownsarahm
# 24  41898282  github-actions[bot]      github-actions
# 25  10656079          brownsarahm         brownsarahm
# 26  10656079          brownsarahm         brownsarahm
# 27  10656079          brownsarahm         brownsarahm
# 28  41898282  github-actions[bot]      github-actions
# 29  10656079          brownsarahm         brownsarahm
#
#                                            actor_url  \
# 0           https://api.github.com/users/brownsarahm
# 1           https://api.github.com/users/brownsarahm
# 2   https://api.github.com/users/github-actions[bot]
# 3           https://api.github.com/users/brownsarahm
# 4   https://api.github.com/users/github-actions[bot]
# 5   https://api.github.com/users/github-actions[bot]
# 6           https://api.github.com/users/brownsarahm
# 7           https://api.github.com/users/brownsarahm
# 8   https://api.github.com/users/github-actions[bot]
# 9   https://api.github.com/users/github-actions[bot]
# 10          https://api.github.com/users/brownsarahm
# 11          https://api.github.com/users/brownsarahm
# 12  https://api.github.com/users/github-actions[bot]
# 13          https://api.github.com/users/brownsarahm
# 14          https://api.github.com/users/brownsarahm
# 15          https://api.github.com/users/brownsarahm
# 16  https://api.github.com/users/github-actions[bot]
# 17          https://api.github.com/users/brownsarahm
# 18  https://api.github.com/users/github-actions[bot]
# 19          https://api.github.com/users/brownsarahm
# 20  https://api.github.com/users/github-actions[bot]
# 21          https://api.github.com/users/brownsarahm
# 22          https://api.github.com/users/brownsarahm
# 23          https://api.github.com/users/brownsarahm
# 24  https://api.github.com/users/github-actions[bot]
# 25          https://api.github.com/users/brownsarahm
# 26          https://api.github.com/users/brownsarahm
# 27          https://api.github.com/users/brownsarahm
# 28  https://api.github.com/users/github-actions[bot]
# 29          https://api.github.com/users/brownsarahm
#
#                                      actor_avatar_url    repo_id  \
# 0   https://avatars.githubusercontent.com/u/10656079?  532028859
# 1   https://avatars.githubusercontent.com/u/10656079?  532028859
https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 2   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 3   https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 4   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 5   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 6   https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 7   https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 8   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 9   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 10  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 11  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 12  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 13  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 14  https://api.github.com/repos/rhodyprog4ds/Brow...                  c27
# 15  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 16  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 17  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 18  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 19  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 20  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 21  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 22  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 23  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 24  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 25  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 26  https://api.github.com/repos/rhodyprog4ds/Brow...                  c26
# 27  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 28  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 29  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
#
#     ...                            payload_before  \
# 0   ...                                       NaN
# 1   ...  ac2160155ae965ac5244413ee4c1dbaaeb35ccaf
# 2   ...  ad28375f9703319d32ebb6c12da364b6497b4404
# 3   ...  abebc1f0a53d61324d4eb065f5382e0e9e9e3653
# 4   ...  4a55b9e6de7dab488d6e94acd3582817b12ccbe9
# 5   ...  dfcb25065771ab6bda4a8d71c8dfad644d4802a7
# 6   ...  68204526add6f1520f015b7d5d56623b788ae3cd
# 7   ...  63727888c8534e30904a3e861d5d7577aaca2f11
# 8   ...  f78b6725c4da8ad05aaf13b4b35675d63f83df23
# 9   ...  86c437bd06ef3316dfa757de1950afec91cd7f1e
# 10  ...  ac15626f7d5446ad75b2c5275d51064da3fef8f5
# 11  ...  49f8bc6e20fb6121c59a3b1ffd336348adda54bd
# 12  ...  2b3c332b0a9f519caf5db7f587b93283357b79c5
# 13  ...                                       NaN
# 14  ...                                       NaN
# 15  ...  327f0de48096628636911e6735f51af6c66291bb
# 16  ...  27fd4444bdd9269fb83fd4660009b7ce83828717
# 17  ...  972fa20a0af61e6f4cc0a16cecee0da188c0055d
# 18  ...  37222cbb373ca45d08e61b7a68f62f121bdf5272
# 19  ...  992241ff235eaca1af3dc481dd0b9271e8b20256
# 20  ...  e0a94cb4ed2cf6acc901e4110f89fe87934890ab
# 21  ...                                       NaN
# 22  ...  f801ef370cb979ad716d9b2ea12f17d61c74ba6d
# 23  ...                                       NaN
# 24  ...  f8b9308f2355fdd856b458aa6b56d9af41496e94
# 25  ...                                       NaN
# 26  ...                                       NaN
# 27  ...  d06b0ec8d75bcf0d035cf189f8430174e7b1cb5f
# 28  ...  69b5b579a9e5df7dc5fb2afeaad051ce841050a6
# 29  ...  8eb670dc6d70578e1324c8c2ba475245fe27cd1e
#
#                                       payload_commits payload_action  \
# 0                                                 NaN            NaN
# 1   [{'sha': '881aeec1cac8e2df50ca1f76b6511191e2e2...            NaN
# 2   [{'sha': '877af3815420d0575ca99daf6da6e85325ae...            NaN
# 3   [{'sha': 'ac2160155ae965ac5244413ee4c1dbaaeb35...            NaN
# 4   [{'sha': 'ad28375f9703319d32ebb6c12da364b6497b...            NaN
# 5   [{'sha': '4a55b9e6de7dab488d6e94acd3582817b12c...            NaN
# 6   [{'sha': 'abebc1f0a53d61324d4eb065f5382e0e9e9e...            NaN
# 7   [{'sha': '68204526add6f1520f015b7d5d56623b788a...            NaN
# 8   [{'sha': 'dfcb25065771ab6bda4a8d71c8dfad644d48...            NaN
# 9   [{'sha': 'f78b6725c4da8ad05aaf13b4b35675d63f83...            NaN
# 10  [{'sha': '63727888c8534e30904a3e861d5d7577aaca...            NaN
# 11  [{'sha': 'ac15626f7d5446ad75b2c5275d51064da3fe...            NaN
# 12  [{'sha': '86c437bd06ef3316dfa757de1950afec91cd...            NaN
# 13                                                NaN      published
# 14                                                NaN            NaN
# 15  [{'sha': 'e739321a0bc750cf81bb9ae6be99c2bebebc...            NaN
# 16  [{'sha': '2b3c332b0a9f519caf5db7f587b93283357b...            NaN
# 17  [{'sha': 'e286a7fe8b506fd2925989de6656aa86871e...            NaN
# 18  [{'sha': '27fd4444bdd9269fb83fd4660009b7ce8382...            NaN
# 19  [{'sha': '972fa20a0af61e6f4cc0a16cecee0da188c0...            NaN
# 20  [{'sha': '37222cbb373ca45d08e61b7a68f62f121bdf...            NaN
# 21                                                NaN         closed
# 22  [{'sha': '992241ff235eaca1af3dc481dd0b9271e8b2...            NaN
# 23                                                NaN         closed
# 24  [{'sha': 'e0a94cb4ed2cf6acc901e4110f89fe879348...            NaN
# 25                                                NaN      published
# 26                                                NaN            NaN
# 27  [{'sha': 'f801ef370cb979ad716d9b2ea12f17d61c74...            NaN
# 28  [{'sha': 'f8b9308f2355fdd856b458aa6b56d9af4149...            NaN
# 29  [{'sha': 'd06b0ec8d75bcf0d035cf189f8430174e7b1...            NaN
#
#                                       payload_release  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/rhodypro...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/rhodypro...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                         payload_issue    org_id     org_login  \
# 0                                                 NaN  69595187  rhodyprog4ds
# 1                                                 NaN  69595187  rhodyprog4ds
# 2                                                 NaN  69595187  rhodyprog4ds
# 3                                                 NaN  69595187  rhodyprog4ds
# 4                                                 NaN  69595187  rhodyprog4ds
# 5                                                 NaN  69595187  rhodyprog4ds
# 6                                                 NaN  69595187  rhodyprog4ds
# 7                                                 NaN  69595187  rhodyprog4ds
# 8                                                 NaN  69595187  rhodyprog4ds
# 9                                                 NaN  69595187  rhodyprog4ds
# 10                                                NaN  69595187  rhodyprog4ds
# 11                                                NaN  69595187  rhodyprog4ds
# 12                                                NaN  69595187  rhodyprog4ds
# 13                                                NaN  69595187  rhodyprog4ds
# 14                                                NaN  69595187  rhodyprog4ds
# 15                                                NaN  69595187  rhodyprog4ds
# 16                                                NaN  69595187  rhodyprog4ds
# 17                                                NaN  69595187  rhodyprog4ds
# 18                                                NaN  69595187  rhodyprog4ds
# 19                                                NaN  69595187  rhodyprog4ds
# 20                                                NaN  69595187  rhodyprog4ds
# 21  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 22                                                NaN  69595187  rhodyprog4ds
# 23  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 24                                                NaN  69595187  rhodyprog4ds
# 25                                                NaN  69595187  rhodyprog4ds
# 26                                                NaN  69595187  rhodyprog4ds
# 27                                                NaN  69595187  rhodyprog4ds
# 28                                                NaN  69595187  rhodyprog4ds
# 29                                                NaN  69595187  rhodyprog4ds
#
#    org_gravatar_id                                   org_url  \
# 0                   https://api.github.com/orgs/rhodyprog4ds
# 1                   https://api.github.com/orgs/rhodyprog4ds
# 2                   https://api.github.com/orgs/rhodyprog4ds
# [30 rows x 28 columns]

# %% [markdown]
# the `rename` method's `column` parameter can take a lambda defined inline, which is helpful, because we want that function to take one parameter (the current columnt name) and do the same thing to all of the columns within a single DataFrame, but to prepend a different thing for each DataFrame

# %%
pd.concat([course_gh_df[cur_col].apply(pd.Series).rename(columns = lambda c: cur_col + '_' +c)
           for cur_col in js_cols],
         axis=1)
# Out:
#     actor_id          actor_login actor_display_login actor_gravatar_id  \
# 0   10656079          brownsarahm         brownsarahm
# 1   10656079          brownsarahm         brownsarahm
# 2   41898282  github-actions[bot]      github-actions
# 3   10656079          brownsarahm         brownsarahm
# 4   41898282  github-actions[bot]      github-actions
# 5   41898282  github-actions[bot]      github-actions
# 6   10656079          brownsarahm         brownsarahm
# 7   10656079          brownsarahm         brownsarahm
# 8   41898282  github-actions[bot]      github-actions
# 9   41898282  github-actions[bot]      github-actions
# 10  10656079          brownsarahm         brownsarahm
# 11  10656079          brownsarahm         brownsarahm
# 12  41898282  github-actions[bot]      github-actions
# 13  10656079          brownsarahm         brownsarahm
# 14  10656079          brownsarahm         brownsarahm
# 15  10656079          brownsarahm         brownsarahm
# 16  41898282  github-actions[bot]      github-actions
# 17  10656079          brownsarahm         brownsarahm
# 18  41898282  github-actions[bot]      github-actions
# 19  10656079          brownsarahm         brownsarahm
# 20  41898282  github-actions[bot]      github-actions
# 21  10656079          brownsarahm         brownsarahm
# 22  10656079          brownsarahm         brownsarahm
# 23  10656079          brownsarahm         brownsarahm
# 24  41898282  github-actions[bot]      github-actions
# 25  10656079          brownsarahm         brownsarahm
# 26  10656079          brownsarahm         brownsarahm
# 27  10656079          brownsarahm         brownsarahm
# 28  41898282  github-actions[bot]      github-actions
# 29  10656079          brownsarahm         brownsarahm
#
#                                            actor_url  \
# 0           https://api.github.com/users/brownsarahm
# 1           https://api.github.com/users/brownsarahm
# 2   https://api.github.com/users/github-actions[bot]
# 3           https://api.github.com/users/brownsarahm
# 4   https://api.github.com/users/github-actions[bot]
# 5   https://api.github.com/users/github-actions[bot]
# 6           https://api.github.com/users/brownsarahm
# 7           https://api.github.com/users/brownsarahm
# 8   https://api.github.com/users/github-actions[bot]
# 9   https://api.github.com/users/github-actions[bot]
# 10          https://api.github.com/users/brownsarahm
# 11          https://api.github.com/users/brownsarahm
# 12  https://api.github.com/users/github-actions[bot]
# 13          https://api.github.com/users/brownsarahm
# 14          https://api.github.com/users/brownsarahm
# 15          https://api.github.com/users/brownsarahm
# 16  https://api.github.com/users/github-actions[bot]
# 17          https://api.github.com/users/brownsarahm
# 18  https://api.github.com/users/github-actions[bot]
# 19          https://api.github.com/users/brownsarahm
# 20  https://api.github.com/users/github-actions[bot]
# 21          https://api.github.com/users/brownsarahm
# 22          https://api.github.com/users/brownsarahm
# 23          https://api.github.com/users/brownsarahm
# 24  https://api.github.com/users/github-actions[bot]
# 25          https://api.github.com/users/brownsarahm
# 26          https://api.github.com/users/brownsarahm
# 27          https://api.github.com/users/brownsarahm
# 28  https://api.github.com/users/github-actions[bot]
https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 2   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 3   https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 4   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 5   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 6   https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 7   https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 8   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 9   https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 10  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 11  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 12  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 13  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 14  https://api.github.com/repos/rhodyprog4ds/Brow...                  c27
# 15  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 16  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 17  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 18  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 19  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 20  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 21  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 22  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 23  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 24  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 25  https://api.github.com/repos/rhodyprog4ds/Brow...                  NaN
# 26  https://api.github.com/repos/rhodyprog4ds/Brow...                  c26
# 27  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
# 28  https://api.github.com/repos/rhodyprog4ds/Brow...  refs/heads/gh-pages
# 29  https://api.github.com/repos/rhodyprog4ds/Brow...      refs/heads/main
#
#     ...                            payload_before  \
# 0   ...                                       NaN
# 1   ...  ac2160155ae965ac5244413ee4c1dbaaeb35ccaf
# 2   ...  ad28375f9703319d32ebb6c12da364b6497b4404
# 3   ...  abebc1f0a53d61324d4eb065f5382e0e9e9e3653
# 4   ...  4a55b9e6de7dab488d6e94acd3582817b12ccbe9
# 5   ...  dfcb25065771ab6bda4a8d71c8dfad644d4802a7
# 6   ...  68204526add6f1520f015b7d5d56623b788ae3cd
# 7   ...  63727888c8534e30904a3e861d5d7577aaca2f11
# 8   ...  f78b6725c4da8ad05aaf13b4b35675d63f83df23
# 9   ...  86c437bd06ef3316dfa757de1950afec91cd7f1e
# 10  ...  ac15626f7d5446ad75b2c5275d51064da3fef8f5
# 11  ...  49f8bc6e20fb6121c59a3b1ffd336348adda54bd
# 12  ...  2b3c332b0a9f519caf5db7f587b93283357b79c5
# 13  ...                                       NaN
# 14  ...                                       NaN
# 15  ...  327f0de48096628636911e6735f51af6c66291bb
# 16  ...  27fd4444bdd9269fb83fd4660009b7ce83828717
# 17  ...  972fa20a0af61e6f4cc0a16cecee0da188c0055d
# 18  ...  37222cbb373ca45d08e61b7a68f62f121bdf5272
# 19  ...  992241ff235eaca1af3dc481dd0b9271e8b20256
# 20  ...  e0a94cb4ed2cf6acc901e4110f89fe87934890ab
# 21  ...                                       NaN
# 22  ...  f801ef370cb979ad716d9b2ea12f17d61c74ba6d
# 23  ...                                       NaN
# 24  ...  f8b9308f2355fdd856b458aa6b56d9af41496e94
# 25  ...                                       NaN
# 26  ...                                       NaN
# 27  ...  d06b0ec8d75bcf0d035cf189f8430174e7b1cb5f
# 28  ...  69b5b579a9e5df7dc5fb2afeaad051ce841050a6
# 29  ...  8eb670dc6d70578e1324c8c2ba475245fe27cd1e
#
#                                       payload_commits payload_action  \
# 0                                                 NaN            NaN
# 1   [{'sha': '881aeec1cac8e2df50ca1f76b6511191e2e2...            NaN
# 2   [{'sha': '877af3815420d0575ca99daf6da6e85325ae...            NaN
# 3   [{'sha': 'ac2160155ae965ac5244413ee4c1dbaaeb35...            NaN
# 4   [{'sha': 'ad28375f9703319d32ebb6c12da364b6497b...            NaN
# 5   [{'sha': '4a55b9e6de7dab488d6e94acd3582817b12c...            NaN
# 6   [{'sha': 'abebc1f0a53d61324d4eb065f5382e0e9e9e...            NaN
# 7   [{'sha': '68204526add6f1520f015b7d5d56623b788a...            NaN
# 8   [{'sha': 'dfcb25065771ab6bda4a8d71c8dfad644d48...            NaN
# 9   [{'sha': 'f78b6725c4da8ad05aaf13b4b35675d63f83...            NaN
# 10  [{'sha': '63727888c8534e30904a3e861d5d7577aaca...            NaN
# 11  [{'sha': 'ac15626f7d5446ad75b2c5275d51064da3fe...            NaN
# 12  [{'sha': '86c437bd06ef3316dfa757de1950afec91cd...            NaN
# 13                                                NaN      published
# 14                                                NaN            NaN
# 15  [{'sha': 'e739321a0bc750cf81bb9ae6be99c2bebebc...            NaN
# 16  [{'sha': '2b3c332b0a9f519caf5db7f587b93283357b...            NaN
# 17  [{'sha': 'e286a7fe8b506fd2925989de6656aa86871e...            NaN
# 18  [{'sha': '27fd4444bdd9269fb83fd4660009b7ce8382...            NaN
# 19  [{'sha': '972fa20a0af61e6f4cc0a16cecee0da188c0...            NaN
# 20  [{'sha': '37222cbb373ca45d08e61b7a68f62f121bdf...            NaN
# 21                                                NaN         closed
# 22  [{'sha': '992241ff235eaca1af3dc481dd0b9271e8b2...            NaN
# 23                                                NaN         closed
# 24  [{'sha': 'e0a94cb4ed2cf6acc901e4110f89fe879348...            NaN
# 25                                                NaN      published
# 26                                                NaN            NaN
# 27  [{'sha': 'f801ef370cb979ad716d9b2ea12f17d61c74...            NaN
# 28  [{'sha': 'f8b9308f2355fdd856b458aa6b56d9af4149...            NaN
# 29  [{'sha': 'd06b0ec8d75bcf0d035cf189f8430174e7b1...            NaN
#
#                                       payload_release  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/rhodypro...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/rhodypro...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                         payload_issue    org_id     org_login  \
# 0                                                 NaN  69595187  rhodyprog4ds
# 1                                                 NaN  69595187  rhodyprog4ds
# 2                                                 NaN  69595187  rhodyprog4ds
# 3                                                 NaN  69595187  rhodyprog4ds
# 4                                                 NaN  69595187  rhodyprog4ds
# 5                                                 NaN  69595187  rhodyprog4ds
# 6                                                 NaN  69595187  rhodyprog4ds
# 7                                                 NaN  69595187  rhodyprog4ds
# 8                                                 NaN  69595187  rhodyprog4ds
# 9                                                 NaN  69595187  rhodyprog4ds
# 10                                                NaN  69595187  rhodyprog4ds
# 11                                                NaN  69595187  rhodyprog4ds
# 12                                                NaN  69595187  rhodyprog4ds
# 13                                                NaN  69595187  rhodyprog4ds
# 14                                                NaN  69595187  rhodyprog4ds
# 15                                                NaN  69595187  rhodyprog4ds
# 16                                                NaN  69595187  rhodyprog4ds
# 17                                                NaN  69595187  rhodyprog4ds
# 18                                                NaN  69595187  rhodyprog4ds
# 19                                                NaN  69595187  rhodyprog4ds
# 20                                                NaN  69595187  rhodyprog4ds
# 21  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 22                                                NaN  69595187  rhodyprog4ds
# 23  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 24                                                NaN  69595187  rhodyprog4ds
# 22  https://avatars.githubusercontent.com/u/69595187?
# 23  https://avatars.githubusercontent.com/u/69595187?
# 24  https://avatars.githubusercontent.com/u/69595187?
# 25  https://avatars.githubusercontent.com/u/69595187?
# 26  https://avatars.githubusercontent.com/u/69595187?
# 27  https://avatars.githubusercontent.com/u/69595187?
# 28  https://avatars.githubusercontent.com/u/69595187?
# 29  https://avatars.githubusercontent.com/u/69595187?
#
# [30 rows x 28 columns]

# %% [markdown]
# So now, we have the unpacked columns with good column names, but we lost the columns that were originally good.
#
#
# How can we append the new columns to the old ones?
# First we can make a DataFrame that's just the columns not on the list that we're goign to expand.

# %%
course_gf_df_good = course_gh_df[[col for col in
          course_gh_df.columns if not(col in js_cols)]]
course_gf_df_good
# Out:
#              id          type  public                created_at
# 0   25344402964   CreateEvent    True 2022-11-19 03:18:33+00:00
# 1   25344398675     PushEvent    True 2022-11-19 03:17:50+00:00
# 2   25342083235     PushEvent    True 2022-11-18 22:54:00+00:00
# 3   25341998257     PushEvent    True 2022-11-18 22:47:06+00:00
# 4   25337507441     PushEvent    True 2022-11-18 18:09:53+00:00
# 5   25337490927     PushEvent    True 2022-11-18 18:08:59+00:00
# 6   25337370539     PushEvent    True 2022-11-18 18:02:32+00:00
# 7   25337341579     PushEvent    True 2022-11-18 18:01:04+00:00
# 8   25320624895     PushEvent    True 2022-11-18 03:19:42+00:00
# 9   25320597150     PushEvent    True 2022-11-18 03:17:14+00:00
# 10  25320534974     PushEvent    True 2022-11-18 03:11:38+00:00
# 11  25320514276     PushEvent    True 2022-11-18 03:09:50+00:00
# 12  25144088977     PushEvent    True 2022-11-10 02:48:15+00:00
# 13  25144043727  ReleaseEvent    True 2022-11-10 02:44:25+00:00
# 14  25144027183   CreateEvent    True 2022-11-10 02:43:00+00:00
# 15  25144017610     PushEvent    True 2022-11-10 02:42:09+00:00
# 16  25142512510     PushEvent    True 2022-11-10 00:49:41+00:00
# 17  25142364425     PushEvent    True 2022-11-10 00:40:43+00:00
# 18  25139682863     PushEvent    True 2022-11-09 21:54:16+00:00
# 19  25139577301     PushEvent    True 2022-11-09 21:48:21+00:00
# 20  25139071066     PushEvent    True 2022-11-09 21:18:56+00:00
# 21  25138999879   IssuesEvent    True 2022-11-09 21:14:50+00:00
# 22  25138969075     PushEvent    True 2022-11-09 21:13:04+00:00
# 23  25138947856   IssuesEvent    True 2022-11-09 21:11:50+00:00
# 24  25115458774     PushEvent    True 2022-11-09 01:17:52+00:00
# 25  25087626486  ReleaseEvent    True 2022-11-08 01:56:11+00:00
# 26  25087620296   CreateEvent    True 2022-11-08 01:55:44+00:00
# 27  25087612809     PushEvent    True 2022-11-08 01:55:10+00:00
# 28  25043076741     PushEvent    True 2022-11-05 00:02:20+00:00
# 29  25043031795     PushEvent    True 2022-11-04 23:56:23+00:00

# %% [markdown]
# Then we can prepend that to the list that we pass to `concat`. We have to put it in a list first, then use + to do that.

# %%
pd.concat([course_gf_df_good]+[course_gh_df[col].apply(pd.Series,).rename(
  columns= lambda i_col: col + '_' + i_col )
      for col in js_cols],axis=1)
# Out:
#              id          type  public                created_at  actor_id  \
# 0   25344402964   CreateEvent    True 2022-11-19 03:18:33+00:00  10656079
# 1   25344398675     PushEvent    True 2022-11-19 03:17:50+00:00  10656079
# 2   25342083235     PushEvent    True 2022-11-18 22:54:00+00:00  41898282
# 3   25341998257     PushEvent    True 2022-11-18 22:47:06+00:00  10656079
# 4   25337507441     PushEvent    True 2022-11-18 18:09:53+00:00  41898282
# 5   25337490927     PushEvent    True 2022-11-18 18:08:59+00:00  41898282
# 6   25337370539     PushEvent    True 2022-11-18 18:02:32+00:00  10656079
# 7   25337341579     PushEvent    True 2022-11-18 18:01:04+00:00  10656079
# 8   25320624895     PushEvent    True 2022-11-18 03:19:42+00:00  41898282
# 9   25320597150     PushEvent    True 2022-11-18 03:17:14+00:00  41898282
# 10  25320534974     PushEvent    True 2022-11-18 03:11:38+00:00  10656079
# 11  25320514276     PushEvent    True 2022-11-18 03:09:50+00:00  10656079
# 12  25144088977     PushEvent    True 2022-11-10 02:48:15+00:00  41898282
# 13  25144043727  ReleaseEvent    True 2022-11-10 02:44:25+00:00  10656079
# 14  25144027183   CreateEvent    True 2022-11-10 02:43:00+00:00  10656079
# 15  25144017610     PushEvent    True 2022-11-10 02:42:09+00:00  10656079
# 16  25142512510     PushEvent    True 2022-11-10 00:49:41+00:00  41898282
# 17  25142364425     PushEvent    True 2022-11-10 00:40:43+00:00  10656079
# 18  25139682863     PushEvent    True 2022-11-09 21:54:16+00:00  41898282
# 19  25139577301     PushEvent    True 2022-11-09 21:48:21+00:00  10656079
# 20  25139071066     PushEvent    True 2022-11-09 21:18:56+00:00  41898282
# 21  25138999879   IssuesEvent    True 2022-11-09 21:14:50+00:00  10656079
# 22  25138969075     PushEvent    True 2022-11-09 21:13:04+00:00  10656079
# 23  25138947856   IssuesEvent    True 2022-11-09 21:11:50+00:00  10656079
# 24  25115458774     PushEvent    True 2022-11-09 01:17:52+00:00  41898282
# 25  25087626486  ReleaseEvent    True 2022-11-08 01:56:11+00:00  10656079
# 26  25087620296   CreateEvent    True 2022-11-08 01:55:44+00:00  10656079
# 27  25087612809     PushEvent    True 2022-11-08 01:55:10+00:00  10656079
# 28  25043076741     PushEvent    True 2022-11-05 00:02:20+00:00  41898282
# 29  25043031795     PushEvent    True 2022-11-04 23:56:23+00:00  10656079
#
#             actor_login actor_display_login actor_gravatar_id  \
# 0           brownsarahm         brownsarahm
# 1           brownsarahm         brownsarahm
# 2   github-actions[bot]      github-actions
# 3           brownsarahm         brownsarahm
# 4   github-actions[bot]      github-actions
# 5   github-actions[bot]      github-actions
# 6           brownsarahm         brownsarahm
# 7           brownsarahm         brownsarahm
# 8   github-actions[bot]      github-actions
# 9   github-actions[bot]      github-actions
# 10          brownsarahm         brownsarahm
# 11          brownsarahm         brownsarahm
# 12  github-actions[bot]      github-actions
# 13          brownsarahm         brownsarahm
# 14          brownsarahm         brownsarahm
# 15          brownsarahm         brownsarahm
# 16  github-actions[bot]      github-actions
# 17          brownsarahm         brownsarahm
# 18  github-actions[bot]      github-actions
# 19          brownsarahm         brownsarahm
# 20  github-actions[bot]      github-actions
# 21          brownsarahm         brownsarahm
# 22          brownsarahm         brownsarahm
# 23          brownsarahm         brownsarahm
# 24  github-actions[bot]      github-actions
# 25          brownsarahm         brownsarahm
# 26          brownsarahm         brownsarahm
# 27          brownsarahm         brownsarahm
# 28  github-actions[bot]      github-actions
# 29          brownsarahm         brownsarahm
#
#                                            actor_url  \
# 0           https://api.github.com/users/brownsarahm
# 1           https://api.github.com/users/brownsarahm
# 2   https://api.github.com/users/github-actions[bot]
# 3           https://api.github.com/users/brownsarahm
# 4   https://api.github.com/users/github-actions[bot]
# 5   https://api.github.com/users/github-actions[bot]
# 6           https://api.github.com/users/brownsarahm
# 7           https://api.github.com/users/brownsarahm
# 8   https://api.github.com/users/github-actions[bot]
# 9   https://api.github.com/users/github-actions[bot]
# 10          https://api.github.com/users/brownsarahm
# 11          https://api.github.com/users/brownsarahm
# 12  https://api.github.com/users/github-actions[bot]
# 13          https://api.github.com/users/brownsarahm
# 14          https://api.github.com/users/brownsarahm
# 15          https://api.github.com/users/brownsarahm
# 16  https://api.github.com/users/github-actions[bot]
# 17          https://api.github.com/users/brownsarahm
# 18  https://api.github.com/users/github-actions[bot]
# 19          https://api.github.com/users/brownsarahm
# 20  https://api.github.com/users/github-actions[bot]
# 21          https://api.github.com/users/brownsarahm
# 22          https://api.github.com/users/brownsarahm
# 23          https://api.github.com/users/brownsarahm
# 24  https://api.github.com/users/github-actions[bot]
# 25          https://api.github.com/users/brownsarahm
# 26          https://api.github.com/users/brownsarahm
# 27          https://api.github.com/users/brownsarahm
# 28  https://api.github.com/users/github-actions[bot]
# 29          https://api.github.com/users/brownsarahm
#
#                                      actor_avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/10656079?  ...
# 1   https://avatars.githubusercontent.com/u/10656079?  ...
# 2   https://avatars.githubusercontent.com/u/41898282?  ...
# 3   https://avatars.githubusercontent.com/u/10656079?  ...
# 4   https://avatars.githubusercontent.com/u/41898282?  ...
# 5   https://avatars.githubusercontent.com/u/41898282?  ...
# 6   https://avatars.githubusercontent.com/u/10656079?  ...
# 7   https://avatars.githubusercontent.com/u/10656079?  ...
# 8   https://avatars.githubusercontent.com/u/41898282?  ...
# 9   https://avatars.githubusercontent.com/u/41898282?  ...
# 10  https://avatars.githubusercontent.com/u/10656079?  ...
# 11  https://avatars.githubusercontent.com/u/10656079?  ...
# 12  https://avatars.githubusercontent.com/u/41898282?  ...
# 13  https://avatars.githubusercontent.com/u/10656079?  ...
# 14  https://avatars.githubusercontent.com/u/10656079?  ...
# 15  https://avatars.githubusercontent.com/u/10656079?  ...
# 16  https://avatars.githubusercontent.com/u/41898282?  ...
# 17  https://avatars.githubusercontent.com/u/10656079?  ...
# 18  https://avatars.githubusercontent.com/u/41898282?  ...
# 19  https://avatars.githubusercontent.com/u/10656079?  ...
# 20  https://avatars.githubusercontent.com/u/41898282?  ...
# 21  https://avatars.githubusercontent.com/u/10656079?  ...
# 22  https://avatars.githubusercontent.com/u/10656079?  ...
# 23  https://avatars.githubusercontent.com/u/10656079?  ...
# 24  https://avatars.githubusercontent.com/u/41898282?  ...
# 25  https://avatars.githubusercontent.com/u/10656079?  ...
# 26  https://avatars.githubusercontent.com/u/10656079?  ...
# 27  https://avatars.githubusercontent.com/u/10656079?  ...
# 28  https://avatars.githubusercontent.com/u/41898282?  ...
# 29  https://avatars.githubusercontent.com/u/10656079?  ...
#
#                               payload_before  \
# 0                                        NaN
# 1   ac2160155ae965ac5244413ee4c1dbaaeb35ccaf
# 2   ad28375f9703319d32ebb6c12da364b6497b4404
# 3   abebc1f0a53d61324d4eb065f5382e0e9e9e3653
# 4   4a55b9e6de7dab488d6e94acd3582817b12ccbe9
# 5   dfcb25065771ab6bda4a8d71c8dfad644d4802a7
# 6   68204526add6f1520f015b7d5d56623b788ae3cd
# 7   63727888c8534e30904a3e861d5d7577aaca2f11
# 8   f78b6725c4da8ad05aaf13b4b35675d63f83df23
# 9   86c437bd06ef3316dfa757de1950afec91cd7f1e
# 10  ac15626f7d5446ad75b2c5275d51064da3fef8f5
# 11  49f8bc6e20fb6121c59a3b1ffd336348adda54bd
# 12  2b3c332b0a9f519caf5db7f587b93283357b79c5
# 13                                       NaN
# 14                                       NaN
# 15  327f0de48096628636911e6735f51af6c66291bb
# 16  27fd4444bdd9269fb83fd4660009b7ce83828717
# 17  972fa20a0af61e6f4cc0a16cecee0da188c0055d
# 18  37222cbb373ca45d08e61b7a68f62f121bdf5272
# 19  992241ff235eaca1af3dc481dd0b9271e8b20256
# 20  e0a94cb4ed2cf6acc901e4110f89fe87934890ab
# 21                                       NaN
# 22  f801ef370cb979ad716d9b2ea12f17d61c74ba6d
# 23                                       NaN
# 24  f8b9308f2355fdd856b458aa6b56d9af41496e94
# 25                                       NaN
# 26                                       NaN
# 27  d06b0ec8d75bcf0d035cf189f8430174e7b1cb5f
# 28  69b5b579a9e5df7dc5fb2afeaad051ce841050a6
# 29  8eb670dc6d70578e1324c8c2ba475245fe27cd1e
#
#                                       payload_commits payload_action  \
# 0                                                 NaN            NaN
# 1   [{'sha': '881aeec1cac8e2df50ca1f76b6511191e2e2...            NaN
# 2   [{'sha': '877af3815420d0575ca99daf6da6e85325ae...            NaN
# 3   [{'sha': 'ac2160155ae965ac5244413ee4c1dbaaeb35...            NaN
# 4   [{'sha': 'ad28375f9703319d32ebb6c12da364b6497b...            NaN
# 5   [{'sha': '4a55b9e6de7dab488d6e94acd3582817b12c...            NaN
# 6   [{'sha': 'abebc1f0a53d61324d4eb065f5382e0e9e9e...            NaN
# 7   [{'sha': '68204526add6f1520f015b7d5d56623b788a...            NaN
# 8   [{'sha': 'dfcb25065771ab6bda4a8d71c8dfad644d48...            NaN
# 9   [{'sha': 'f78b6725c4da8ad05aaf13b4b35675d63f83...            NaN
# 10  [{'sha': '63727888c8534e30904a3e861d5d7577aaca...            NaN
# 11  [{'sha': 'ac15626f7d5446ad75b2c5275d51064da3fe...            NaN
# 12  [{'sha': '86c437bd06ef3316dfa757de1950afec91cd...            NaN
# 13                                                NaN      published
# 14                                                NaN            NaN
# 15  [{'sha': 'e739321a0bc750cf81bb9ae6be99c2bebebc...            NaN
# 16  [{'sha': '2b3c332b0a9f519caf5db7f587b93283357b...            NaN
# 17  [{'sha': 'e286a7fe8b506fd2925989de6656aa86871e...            NaN
# 18  [{'sha': '27fd4444bdd9269fb83fd4660009b7ce8382...            NaN
# 19  [{'sha': '972fa20a0af61e6f4cc0a16cecee0da188c0...            NaN
# 20  [{'sha': '37222cbb373ca45d08e61b7a68f62f121bdf...            NaN
# 21                                                NaN         closed
# 22  [{'sha': '992241ff235eaca1af3dc481dd0b9271e8b2...            NaN
# 23                                                NaN         closed
# 24  [{'sha': 'e0a94cb4ed2cf6acc901e4110f89fe879348...            NaN
# 25                                                NaN      published
# 26                                                NaN            NaN
# 27  [{'sha': 'f801ef370cb979ad716d9b2ea12f17d61c74...            NaN
# 28  [{'sha': 'f8b9308f2355fdd856b458aa6b56d9af4149...            NaN
# 29  [{'sha': 'd06b0ec8d75bcf0d035cf189f8430174e7b1...            NaN
#
#                                       payload_release  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/rhodypro...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/rhodypro...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                         payload_issue    org_id     org_login  \
# 0                                                 NaN  69595187  rhodyprog4ds
# 1                                                 NaN  69595187  rhodyprog4ds
# 2                                                 NaN  69595187  rhodyprog4ds
# 3                                                 NaN  69595187  rhodyprog4ds
# 4                                                 NaN  69595187  rhodyprog4ds
# 5                                                 NaN  69595187  rhodyprog4ds
# 6                                                 NaN  69595187  rhodyprog4ds
# 7                                                 NaN  69595187  rhodyprog4ds
# 8                                                 NaN  69595187  rhodyprog4ds
# 9                                                 NaN  69595187  rhodyprog4ds
# 10                                                NaN  69595187  rhodyprog4ds
# 11                                                NaN  69595187  rhodyprog4ds
# 12                                                NaN  69595187  rhodyprog4ds
# 13                                                NaN  69595187  rhodyprog4ds
# 14                                                NaN  69595187  rhodyprog4ds
# 15                                                NaN  69595187  rhodyprog4ds
# 16                                                NaN  69595187  rhodyprog4ds
# 17                                                NaN  69595187  rhodyprog4ds
# 18                                                NaN  69595187  rhodyprog4ds
# 19                                                NaN  69595187  rhodyprog4ds
# 20                                                NaN  69595187  rhodyprog4ds
# 21  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 22                                                NaN  69595187  rhodyprog4ds
# 23  {'url': 'https://api.github.com/repos/rhodypro...  69595187  rhodyprog4ds
# 24                                                NaN  69595187  rhodyprog4ds
# 25                                                NaN  69595187  rhodyprog4ds
# 26                                                NaN  69595187  rhodyprog4ds
# 27                                                NaN  69595187  rhodyprog4ds
# 28                                                NaN  69595187  rhodyprog4ds
# 29                                                NaN  69595187  rhodyprog4ds
#
#    org_gravatar_id                                   org_url  \
# 0                   https://api.github.com/orgs/rhodyprog4ds
# 1                   https://api.github.com/orgs/rhodyprog4ds
# 2                   https://api.github.com/orgs/rhodyprog4ds
