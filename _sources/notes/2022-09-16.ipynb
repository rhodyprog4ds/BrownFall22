# %% [markdown]
# # Iterables and Indexing
#
# ## Logistics
#
#
# ### Assignment
# On Assignment 2, there's a script to run to prepare it for grading.
#
# ````{important}
# I missed a file in the template, so please create a file called requirements.txt that has the following contents.
# ```
# jupyter-book
# pyppeteer
# pandas
# jupytext
# ```
# ````
#
# Correct script file (for .githu/workflows/submit.yml)
#
# ```
# name: Prepare and Submit
# on:
#   workflow_dispatch
#
# jobs:
#   generatereport:
#     runs-on: ubuntu-latest
#     steps:
#     - uses: actions/checkout@v2
#
#     # Install dependencies
#     - name: Set up Python 3.9
#       uses: actions/setup-python@v1
#       with:
#         python-version: 3.9
#
#     # install dependencies
#     - name: dependencies
#       run: pip install -r requirements.txt
#
#     # generate the report
#     - name: Convert notebooks to md for reading
#       run: |
#         jupytext --to myst *.ipynb
#         jupytext --to myst */*.ipynb
#
#     # compile the pdf
#     - name: Build a basic html to pdf
#       run: |
#         jupyter-book build *.ipynb --builder pdfhtml
#
#     # start a pull request for it
#     - name: Create Pull Request
#       uses: peter-evans/create-pull-request@v4
#       with:
#         commit-message: 'convert to md'
#         draft: false
#         branch: published
#         base: main
#         title: Submission
# ```
#
# Add this to `.gitignore`
#
# ```
# _build/
# ```
#
# How to apply these updates:
#
# <iframe src="https://scribehow.com/embed/Github_Workflow__NV48Md3wQE26wpEj_ijf-A" width="640" height="640" allowfullscreen frameborder="0"></iframe>
#
# [full view](https://scribehow.com/shared/Github_Workflow__NV48Md3wQE26wpEj_ijf-A)
#
#
#
# To run the script
#
# <iframe src="https://scribehow.com/embed/Manually_Run_GitHub_action__gDGjXhWyTCOr-XoMBqls7w" width="640" height="640" allowfullscreen frameborder="0"></iframe>
#
# [see instructions in a full page](https://scribehow.com/shared/Manually_Run_GitHub_action__gDGjXhWyTCOr-XoMBqls7w)
#
# ### Grade Tracking
#
# ````{margin}
# ```{note}
# Are these scribe screenshots helpful? do you want more of them?
# ```
# ````
#
#
#
# Create a Project board
#
# <iframe src="https://scribehow.com/embed/create_a_private_project__nUx_RZSATA6ZfNJsrzO22g" width="640" height="640" allowfullscreen frameborder="0"></iframe>
#
#
# Then [create your repo](https://classroom.github.com/a/1jyhkSZP) and  run the manual workflow on that actions tab to create issues:
#
# <iframe src="https://scribehow.com/embed/Github_Workflow__RHLqigCcRUGAtEzTW9uoVg" width="640" height="640" allowfullscreen frameborder="0"></iframe>
#
#
# ## Lists of lists

# %%
import pandas as pd

# %% [markdown]
# Recall how indexing works with negagive numbers

# %%
topics = ['what is data science', 'jupyter', 'conditional','functions', 'lists', 'dictionaries','pandas' ]

# %%
topics[-1]
# Out:
# 'pandas'

# %% [markdown]
# A list we built together:

# %%
# You can remain anonymous (this page & the notes will be fully public)
# by attributing it to a celebrity or psuedonym, but include *some* sort of attribution
sentence_list = [
"The class is just starting to feel settled for me. - Dr. Brown",
"",
"Hello, I like sushi! - ",
"Why squared  aka the mask - is a computer science student."
"Data science is fun",
"Hello my fellow gaymers - Sun Tzu",
"Soccer is a sport -Obama",
"Hello, I love pizza - Bear",
"This class is CSC/DSP 310. - Student",
"It is 2:21pm -",
"Pizza conquers all- Beetlejuice"
"",
"ayyy whaddup wit it - frankie",
"This is a sentence - George W Bush",
"Steam is the best place to play videogames change my mind. - Todd Howard",
"This is a hello -",
"Hello how are you -",
"The monkey likes bananas. - A banana",
"",
"Just type a random sentence - Rosa Parks",
"",
"I love CSC. - Everyone",
"",
"The quick brown fox jumps over the lazy dog - Brendan Chadwick",
"I like computers - David",
"",
"The fitness gram pacer test is a multi aerobic capacity test - Matt 3",
"Sally sells seashells by the seashore. - Narrator",
"I would like to take a nap. - Tom Cruise,"
]

# %% [markdown]
# We can confirm this is a list

# %%
type(sentence_list)
# Out:
# list

# %% [markdown]
# We can use a list comprehension to remove the empty ones.

# %%
sentences_clean = [s for s in sentence_list if len(s)>1]
sentences_clean
# Out:
# ['The class is just starting to feel settled for me. - Dr. Brown',
#  'Hello, I like sushi! - ',
#  'Why squared  aka the mask - is a computer science student.Data science is fun',
#  'Hello my fellow gaymers - Sun Tzu',
#  'Soccer is a sport -Obama',
#  'Hello, I love pizza - Bear',
#  'This class is CSC/DSP 310. - Student',
#  'It is 2:21pm -',
#  'Pizza conquers all- Beetlejuice',
#  'ayyy whaddup wit it - frankie',
#  'This is a sentence - George W Bush',
#  'Steam is the best place to play videogames change my mind. - Todd Howard',
#  'This is a hello -',
#  'Hello how are you -',
#  'The monkey likes bananas. - A banana',
#  'Just type a random sentence - Rosa Parks',
#  'I love CSC. - Everyone',
#  'The quick brown fox jumps over the lazy dog - Brendan Chadwick',
#  'I like computers - David',
#  'The fitness gram pacer test is a multi aerobic capacity test - Matt 3',
#  'Sally sells seashells by the seashore. - Narrator',
#  'I would like to take a nap. - Tom Cruise,']

# %% [markdown]
# We can use the `split` method on a string to make a list of lists

# %%
sentence_data = [s.split('-') for s in sentences_clean]
sentence_data
# Out:
# [['The class is just starting to feel settled for me. ', ' Dr. Brown'],
#  ['Hello, I like sushi! ', ' '],
#  ['Why squared  aka the mask ',
#   ' is a computer science student.Data science is fun'],
#  ['Hello my fellow gaymers ', ' Sun Tzu'],
#  ['Soccer is a sport ', 'Obama'],
#  ['Hello, I love pizza ', ' Bear'],
#  ['This class is CSC/DSP 310. ', ' Student'],
#  ['It is 2:21pm ', ''],
#  ['Pizza conquers all', ' Beetlejuice'],
#  ['ayyy whaddup wit it ', ' frankie'],
#  ['This is a sentence ', ' George W Bush'],
#  ['Steam is the best place to play videogames change my mind. ',
#   ' Todd Howard'],
#  ['This is a hello ', ''],
#  ['Hello how are you ', ''],
#  ['The monkey likes bananas. ', ' A banana'],
#  ['Just type a random sentence ', ' Rosa Parks'],
#  ['I love CSC. ', ' Everyone'],
#  ['The quick brown fox jumps over the lazy dog ', ' Brendan Chadwick'],
#  ['I like computers ', ' David'],
#  ['The fitness gram pacer test is a multi aerobic capacity test ', ' Matt 3'],
#  ['Sally sells seashells by the seashore. ', ' Narrator'],
#  ['I would like to take a nap. ', ' Tom Cruise,']]

# %% [markdown]
# then we can use the [DataFrame Constructor](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html))

# %%
sentence_df = pd.DataFrame(data= sentence_data, columns=['sentence','attribution'])

# %% [markdown]
# We can use head by default for 5

# %%
sentence_df.head()
# Out:
#                                             sentence  \
# 0  The class is just starting to feel settled for...
# 1                              Hello, I like sushi!
# 2                         Why squared  aka the mask
# 3                           Hello my fellow gaymers
# 4                                 Soccer is a sport
#
#                                          attribution
# 0                                          Dr. Brown
# 1
# 2   is a computer science student.Data science is...
# 3                                            Sun Tzu
# 4                                              Obama

# %% [markdown]
# or pass a nubmer to get a different  number of rows

# %%
sentence_df.head(3)
# Out:
#                                             sentence  \
# 0  The class is just starting to feel settled for...
# 1                              Hello, I like sushi!
# 2                         Why squared  aka the mask
#
#                                          attribution
# 0                                          Dr. Brown
# 1
# 2   is a computer science student.Data science is...

# %% [markdown]
# the `loc` property can index on rows or columns, but is rows by deault

# %%
sentence_df.loc[3]
# Out:
# sentence       Hello my fellow gaymers
# attribution                     Sun Tzu
# Name: 3, dtype: object

# %% [markdown]
# We can select a range, like in base python with a colon

# %%
sentence_df.loc[3:5]
# Out:
#                    sentence attribution
# 3  Hello my fellow gaymers      Sun Tzu
# 4        Soccer is a sport        Obama
# 5      Hello, I love pizza         Bear

# %% [markdown]
# ## Loading a json
#
# We can load a json using the `read_json` method the same way we used the `read_csv`

# %%
rhodyprog4ds_gh_events_url = 'https://api.github.com/orgs/rhodyprog4ds/events'

# %%
pd.read_json(rhodyprog4ds_gh_events_url)
# Out:
#              id               type  \
# 0   25443352568        CreateEvent
# 1   25443343932          PushEvent
# 2   25390211963          PushEvent
# 3   25390113561       ReleaseEvent
# 4   25390087086        CreateEvent
# 5   25390070156          PushEvent
# 6   25360316947        IssuesEvent
# 7   25360316900  IssueCommentEvent
# 8   25360154325          PushEvent
# 9   25360116113       ReleaseEvent
# 10  25360107585        CreateEvent
# 11  25360103740          PushEvent
# 12  25350056101        IssuesEvent
# 13  25344448847          PushEvent
# 14  25344423864       ReleaseEvent
# 15  25344402964        CreateEvent
# 16  25344398675          PushEvent
# 17  25342083235          PushEvent
# 18  25341998257          PushEvent
# 19  25337507441          PushEvent
# 20  25337490927          PushEvent
# 21  25337370539          PushEvent
# 22  25337341579          PushEvent
# 23  25320624895          PushEvent
# 24  25320597150          PushEvent
# 25  25320534974          PushEvent
# 26  25320514276          PushEvent
# 27  25144088977          PushEvent
# 28  25144043727       ReleaseEvent
# 29  25144027183        CreateEvent
#
#                                                 actor  \
# 0   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 1   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 2   {'id': 41898282, 'login': 'github-actions[bot]...
# 3   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 4   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 5   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 6   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 7   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 8   {'id': 41898282, 'login': 'github-actions[bot]...
# 9   {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 10  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 11  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 12  {'id': 54962132, 'login': 'saidafern', 'displa...
# 13  {'id': 41898282, 'login': 'github-actions[bot]...
# 14  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 15  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 16  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 17  {'id': 41898282, 'login': 'github-actions[bot]...
# 18  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 19  {'id': 41898282, 'login': 'github-actions[bot]...
# 20  {'id': 41898282, 'login': 'github-actions[bot]...
# 21  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 22  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 23  {'id': 41898282, 'login': 'github-actions[bot]...
# 24  {'id': 41898282, 'login': 'github-actions[bot]...
# 25  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 26  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 10656079, 'login': 'brownsarahm', 'disp...
# 29  {'id': 10656079, 'login': 'brownsarahm', 'disp...
#
#                                                  repo  \
# 0   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 1   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 2   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 3   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 4   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 5   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 6   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 7   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 8   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 9   {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 10  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 11  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 12  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 13  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 14  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 15  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 16  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 17  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 18  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 19  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 20  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 21  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 22  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 23  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 24  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 25  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 26  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 27  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 28  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
# 29  {'id': 532028859, 'name': 'rhodyprog4ds/BrownF...
#
#                                               payload  public  \
# 0   {'ref': 'c30', 'ref_type': 'tag', 'master_bran...    True
# 1   {'push_id': 11769742784, 'size': 1, 'distinct_...    True
# 2   {'push_id': 11742950045, 'size': 1, 'distinct_...    True
# 3   {'action': 'published', 'release': {'url': 'ht...    True
# 4   {'ref': 'c29', 'ref_type': 'tag', 'master_bran...    True
# 5   {'push_id': 11742876923, 'size': 1, 'distinct_...    True
# 6   {'action': 'closed', 'issue': {'url': 'https:/...    True
# 7   {'action': 'created', 'issue': {'url': 'https:...    True
# 8   {'push_id': 11727571002, 'size': 1, 'distinct_...    True
# 9   {'action': 'published', 'release': {'url': 'ht...    True
# 10  {'ref': 'a11.1', 'ref_type': 'tag', 'master_br...    True
# 11  {'push_id': 11727536196, 'size': 1, 'distinct_...    True
# 12  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 13  {'push_id': 11716990555, 'size': 1, 'distinct_...    True
# 14  {'action': 'published', 'release': {'url': 'ht...    True
# 15  {'ref': 'c28', 'ref_type': 'tag', 'master_bran...    True
# 16  {'push_id': 11716960749, 'size': 1, 'distinct_...    True
# 17  {'push_id': 11715655053, 'size': 1, 'distinct_...    True
# 18  {'push_id': 11715611559, 'size': 1, 'distinct_...    True
# 19  {'push_id': 11713342480, 'size': 1, 'distinct_...    True
# 20  {'push_id': 11713334159, 'size': 1, 'distinct_...    True
# 21  {'push_id': 11713273804, 'size': 1, 'distinct_...    True
# 22  {'push_id': 11713260064, 'size': 1, 'distinct_...    True
# 23  {'push_id': 11704759224, 'size': 1, 'distinct_...    True
# 24  {'push_id': 11704744417, 'size': 1, 'distinct_...    True
# 25  {'push_id': 11704710069, 'size': 1, 'distinct_...    True
# 26  {'push_id': 11704698397, 'size': 1, 'distinct_...    True
# 27  {'push_id': 11613190412, 'size': 1, 'distinct_...    True
# 28  {'action': 'published', 'release': {'url': 'ht...    True
# 29  {'ref': 'c27', 'ref_type': 'tag', 'master_bran...    True
#
#                   created_at  \
# 0  2022-11-24 02:05:18+00:00
# 1  2022-11-24 02:04:31+00:00
# 2  2022-11-22 02:55:20+00:00
# 3  2022-11-22 02:47:58+00:00
# 4  2022-11-22 02:45:58+00:00
# 5  2022-11-22 02:44:44+00:00
# 6  2022-11-20 20:24:42+00:00
# 7  2022-11-20 20:24:42+00:00
# 8  2022-11-20 20:02:45+00:00
# 9  2022-11-20 19:57:26+00:00
# 10 2022-11-20 19:56:11+00:00
# 11 2022-11-20 19:55:39+00:00
# 12 2022-11-19 17:05:46+00:00
# 13 2022-11-19 03:25:34+00:00
# 14 2022-11-19 03:21:33+00:00
# 15 2022-11-19 03:18:33+00:00
# 16 2022-11-19 03:17:50+00:00
# 17 2022-11-18 22:54:00+00:00
# 18 2022-11-18 22:47:06+00:00
# 19 2022-11-18 18:09:53+00:00
# 20 2022-11-18 18:08:59+00:00
# 21 2022-11-18 18:02:32+00:00
# 22 2022-11-18 18:01:04+00:00
# 23 2022-11-18 03:19:42+00:00
# 24 2022-11-18 03:17:14+00:00
# 25 2022-11-18 03:11:38+00:00
# 26 2022-11-18 03:09:50+00:00
# 27 2022-11-10 02:48:15+00:00
# 28 2022-11-10 02:44:25+00:00
# 29 2022-11-10 02:43:00+00:00
#
#                                                   org
# 0   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 1   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 2   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 3   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 4   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 5   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 6   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 7   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 8   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 9   {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 10  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 11  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 12  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 13  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 14  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 15  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 16  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 17  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 18  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 19  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 20  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 21  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 22  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 23  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 24  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 25  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 26  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 27  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 28  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...
# 29  {'id': 69595187, 'login': 'rhodyprog4ds', 'gra...

# %% [markdown]
# (ghoffline)=
# ## Working with your repo offline
#
# ```{warning}
# This was not done in class and is optional
# ```
#
#
# ### Authenticate on Mac
# On macOS install [GitHub CLI](https://cli.github.com/)
#
# ```
# gh auth login
# ```
#
# use defualts and choose to log in via browser.
#
#
# ### Authenticate on Windows
# On winows install [GitBash](https://gitforwindows.org/)
#
# Then try to do the clone step and GitBash will help you authenticate
#
#
#
# ### Work offline
# Get your repo URL:
#
# <iframe src="https://scribehow.com/embed/Get_your_repo_URP__83HK6IIFQGyZ63s3rED-hw" width="640" height="640" allowfullscreen frameborder="0"></iframe>
#
# `cd` to where you want to save
# ```bash
# cd prog4ds
# git clone https://github.com/rhodyprog4ds/02-loading-data-brownsarahm.git
# ```
#
#
# work in the new folder that creates
#
# When you want to Save
#
# ```bash
# git add .
# git commit -m 'describe the work you did'
# git push
# ```
#
#
#
# ## Questions After Class
#
#
#
# ### Logistics
#
# #### where do we find the grading page?
#
# <iframe src="https://scribehow.com/embed/Find_your_grade_tracking_project_board__jH1mXUbhQFakUXBZuuk6iw" width="640" height="640" allowfullscreen frameborder="0"></iframe>
#
# ### Assignemnt
#
# #### what are the keys needed on the dictionaries for the assignment?
# See the `datasets.py` file in the template repo
#
# #### do we have to accept assignment 2 anywhere and if so how
#
# Yes on the assignment page. The link says "accept the assignment"
#
# #### For the purposes of the assignment should we download it locally to work with our notebooks?
#
# Read the instructions carefully on the assignment. It tells you exactly what to do.
#
#
# ### Content
#
# #### How do you locate a specific row and column from a dataframe?
#
# `.loc` accepts both, using a comma to separate. The [docs for `loc`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) have lots of examples.
#
# #### with data sets if there is an error with formatting and we can modify the original how would we fix it
#
# Download to a copy where you can edit.
#
# #### Can you use .loc to pull out multiple rows that aren't next to each other. For example, if I wanted to view rows 3, 8 and 12
#
# Yes, to select multiple nonconsecutive, you pass a list. The [docs for `loc`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) have lots of examples.
#
# #### how can we iterate through dictionaries
#
# dictionaries have a `.items()` method that pops off tuples of th key and value.
#
# ```{warning}
# the assignment does not ask you to iterate through a dictionary object, but over a list of dictionaries
# ```
#
# #### What is the main differnce between JSON and csv files; does one allocate more memory / store larger sets?
#
# The main difference is the structure.  JSON can hold nested data.  For example look at the GitHub data that we read in in class.
#
# #### what exactly does json mean / do
#
# [json](https://www.json.org/json-en.html) is a data file format. It is an acronym for JavaScript Object Notation.  It's a popular format for internet content.
#
# #### are nested lists the only way to create DataFrames in python
#
# nested lists are not the only way to create pandas DataFrames, you can also do that from a Dictionary. [see in the docs for the constructor](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html).
#
# #### How do nested loops work in the jupyter notebook
#
# Python constructs other than display items work just as they do in any other interpretter in a jupyter notebook.  The list comprehension that we saw today also works in base Python.  You can nest list comphrehenions in different ways depending on your goal.
